# %%
string = r"""
<div class="envContainer equation" id="rvv-es">
          <p class="envHeader">
            Dot product from components.
          </p>
          <div class="envBody">
            <p>
              \[\vec{a} \cdot \vec{b}
              = a_1 b_1 + a_2 b_2 + a_3 b_3\]
            </p>
          </div>
        </div>
      """
# Out:
# '<!DOCTYPE html>\n<html>\n  <head profile="http://www.w3.org/2005/10/profile">\n    <link rel="icon" type="image/png" href="favicon.png">\n    <meta charset="UTF-8">\n    <link href="../style.css" type="text/css" rel="stylesheet" />\n    <link href="../icomoon.css" type="text/css" rel="stylesheet" />\n\n    <script type="text/x-mathjax-config">MathJax.Hub.Config({tex2jax: {inlineMath: [[\'$\',\'$\'], [\'\\\\(\',\'\\\\)\']]}});</script>\n    <script src="../MathJax-master/MathJax.js?config=TeX-AMS-MML_HTMLorMML,local/local"> type = "text/javascript" </script>\n    <!-- <script>\n      MathJax = {\n        tex: {\n          inlineMath: [[\'$\', \'$\'], [\'\\\\(\', \'\\\\)\']]\n        }\n      };\n    </script>\n    <script type="text/javascript" id="MathJax-script" src="../MathJax-master2/es5/tex-mml-chtml.js"></script> -->\n    <script src="../js/jquery-2.1.4.min.js" type="text/javascript"></script>\n    <script src="../js/sylvester.js" type="text/javascript"></script>\n    <script src="../js/sha1.js" type="text/javascript"></script>\n    <script src="../js/PrairieDraw.js" type="text/javascript"></script>\n\n    <script>\n      $(function(){\n        $("#nav-placeholder").load("../nav.html");\n      });\n    </script>\n\n    <script type="text/javascript">\n      var _gaq = _gaq || [];\n      _gaq.push([\'_setAccount\', \'UA-37625161-1\']);\n      _gaq.push([\'_trackPageview\']);\n      (function() {\n        var ga = document.createElement(\'script\'); ga.type = \'text/javascript\'; ga.async = true;\n        ga.src = (\'https:\' == document.location.protocol ? \'https://ssl\' : \'http://www\') + \'.google-analytics.com/ga.js\';\n        var s = document.getElementsByTagName(\'script\')[0]; s.parentNode.insertBefore(ga, s);\n      })();\n    </script>\n    \n    <title>Vectors and bases</title>\n    <script src="rvv_py_triples.js" type="text/javascript"></script>\n    <script src="rvv.js" type="text/javascript"></script>\n    \n    <script src="../js/pageControl.js" type="text/javascript"></script>\n  </head>\n\n  <body>\n    <div class="container">\n      <div class="header"><h1>Dynamics</h1></div>\n      <div id="nav-placeholder"></div>\n      \n      <div class="mainBlock">\n    <div class="contentBlock">\n      <div id="rvv" class="contentCol">\n        <h1>\n          Vectors and bases\n        </h1>\n        <p>\n          A <em>vector</em> is an arrow with a length and a\n          direction. Just like positions, vectors exist before we\n          measure or describe them. Unlike positions, vectors can\n          mean many different things, such as position vectors,\n          velocities, etc. Vectors are not anchored to particular\n          positions in space, so we can slide a vector around and\n          locate it at any position.\n        </p>\n        <div class="figureContainer width400" id="rvv-fc">\n          <canvas id="rvv-fc-c" width="400" height="200" class="figureImage">\n          </canvas>\n          <p class="controls">\n            <button class="anim-toggle:rvv-fc-c">animate</button>\n            <button class="reset:rvv-fc-c">reset</button>\n            Change:\n            <button class="option-toggle:rvv-fc-c:otherLength">length</button>\n            <button class="option-toggle:rvv-fc-c:otherDir">direction</button>\n          </p>\n          <p class="figureCaption">\n            Two vectors, which may or may not be the same\n            vector. Moving a vector around does not change it: it is\n            still the same vector.\n          </p>\n        </div>\n      </div>\n      <div class="infoCol">\n        <div class="infoBox notationBox">\n          <p>\n            Some textbooks differentiate between <em>free\n            vectors</em>, which are free to slide around, and\n            <em>bound vectors</em>, which are anchored in space. We\n            will only use free vectors.\n          </p>\n        </div>\n        <div class="infoBox notationBox">\n          <p>\n            We will u ...

# %%
from bs4 import BeautifulSoup

data = BeautifulSoup(string)

# %%
id = data.find('div')['id']
title = data.find('p').text
td = data.find_all('td')

canvas = [e for e in td[0].contents if e != '\n'][0]

attr_string = ''

for attr, value in canvas.attrs.items():
    attr_string += f'{attr}="{value}" '

pd_canvas = f"<PrairieDrawCanvas {attr_string}/>"

eq = [e for e in td[1].contents if e != '\n'][0]

eq = eq.text.replace('\n', '').replace(' ', '')

eq = eq.replace('\\', '\\\\')

derivation = data.find('div', attrs={'class': 'derivation'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 id = data['id']
#       2 title = data.find('p').text
#       3 td = data.find_all('td')
#
# File /usr/lib/python3.11/site-packages/bs4/element.py:1573, in Tag.__getitem__(self, key)
#    1570 def __getitem__(self, key):
#    1571     """tag[key] returns the value of the 'key' attribute for the Tag,
#    1572     and throws an exception if it's not there."""
# -> 1573     return self.attrs[key]
#
# KeyError: 'id'

# %%
derivation = html.find_all('div', attrs={'class': 'derivation'})

for der in derivation:
    text = str(der.text)
    
    display_equations = re.findall('\[(.*?)\]', text.replace('\n', ''))
    
    disp_eq = ''

    for e in display_equations:
        disp_eq += "<DisplayEquation equation=\"" + e.replace('              ', '').replace('\\', '\\\\') + "\" /> \n"

    #print(disp_eq)

    inline_eq  = re.findall('\$([^$]*?)\$', text.replace('\n', ''))

    i_eq = ''

    for e in inline_eq:
        i_eq += "<InlineEquation equation=\"" + e.replace('              ', '').replace('\\', '\\\\') + "\" /> \n"

    main += f""" 
    <div slot="derivation">
        {disp_eq}

        {i_eq}
    </div>"""

print(main)
# Out:
#
#     <div slot="derivation">
#         <DisplayEquation equation="\\begin{aligned}\\ell^2 &= a_1^2 + a_2^2 \\\\a^2 &= \\ell^2 + a_3^2 = a_1^2 + a_2^2 + a_3^2.\\end{aligned}\\" />
#
#
#         <InlineEquation equation="a" />
# <InlineEquation equation="b" />
# <InlineEquation equation="c" />
# <InlineEquation equation="a^2 + b^2 = c^2" />
#
#     </div>
#     <div slot="derivation">
#         <DisplayEquation equation="\\| \\hat{a} \\| = \\left\\| \\frac{\\vec{a}}{a} \\right\\|= \\frac{\\|\\vec{a}\\|}{a} = \\frac{a}{a} = 1,\\" />
#
#
#         <InlineEquation equation="\\hat{a}" />
# <InlineEquation equation="\\hat{a}" />
# <InlineEquation equation="\\vec{a}" />
#
#     </div>
#     <div slot="derivation">
#
#
#
#     </div>
#     <div slot="derivation">
#         <DisplayEquation equation="\\begin{aligned} a b \\cos\\theta &= a b\\cos(\\theta_b - \\theta_a) \\\\ &= a b (\\cos\\theta_b\\cos\\theta_a + \\sin\\theta_b \\sin\\theta_a)\\end{aligned}\\" />
# <DisplayEquation equation="\\begin{aligned} a b \\cos\\theta &= (a \\cos\\theta_a)(b \\cos\\theta_b) + (a \\sin\\theta_a) (b \\sin\\theta_b) \\\\&= a_1 b_1 + a_2 b_2 \\\\ &= \\vec{a} \\cdot \\vec{b}\\end{aligned}\\" />
#
#
#         <InlineEquation equation="\\vec{a}" />
# <InlineEquation equation="\\vec{b}" />
# <InlineEquation equation="\\theta" />
# <InlineEquation equation="\\theta" />
# <InlineEquation equation="\\vec{a}" />
# <InlineEquation equation="\\vec{b}" />
# <InlineEquation equation="\\theta_a" />
# <InlineEquation equation="\\theta_b" />
# <InlineEquation equation="\\theta_a" />
# <InlineEquation equation="\\theta_b" />
# <InlineEquation equation="\\vec{a}" />
# <InlineEquation equation="\\vec{b}" />
# <InlineEquation equation="a_1 = a \\cos\\theta_a" />
# <InlineEquation equation="a_2 = a \\sin\\theta_a" />
# <InlineEquation equation="\\vec{b}" />
#
#     </div>
#     <div slot="derivation">
#
#
#         <InlineEquation equation="\\vec{a}" />
# <InlineEquation equation="\\theta = 0" />
# <InlineEquation equation="\\vec{a} \\cdot \\vec{a} = a^2 \\cos 0 = a^2" />
#
#     </div>
#     <div slot="derivation">
#         <DisplayEquation equation="\\vec{a} \\cdot \\vec{a}^\\perp= (a_1\\,\\hat\\imath + a_2\\,\\hat\\jmath) \\cdot(-a_2\\,\\hat\\imath + a_1\\hat\\jmath)= -a_1 a_2 + a_2 a_1 = 0.\\" />
#
#
#         <InlineEquation equation="\\vec{a}^\\perp" />
# <InlineEquation equation="\\vec{a}" />
# <InlineEquation equation="\\vec{a}^\\perp" />
# <InlineEquation equation="+90^\\circ" />
# <InlineEquation equation="\\vec{a}" />
#
#     </div>
#     <div slot="derivation">
#         <DisplayEquation equation="\\begin{aligned}            i_1 &= 1 & i_2 &= 0 & i_3 &= 0 \\\\            j_1 &= 0 & j_2 &= 1 & j_3 &= 0 \\\\            k_1 &= 0 & k_2 &= 0 & k_3 &= 1.            \\end{aligned}\\" />
# <DisplayEquation equation="\\begin{aligned}            \\hat\\imath \\times \\hat\\jmath            &= (i_2 j_3 - i_3 j_2) \\,\\hat{\\imath}            + (i_3 j_1 - i_1 j_3) \\,\\hat{\\jmath}            + (i_1 j_2 - i_2 j_1) \\,\\hat{k} \\\\            &= (0 \\times 0 - 0 \\times 1) \\,\\hat{\\imath}            + (0 \\times 0 - 1 \\times 0) \\,\\hat{\\jmath}            + (1 \\times 1 - 0 \\times 0) \\,\\hat{k} \\\\            &= \\hat{k}            \\end{aligned}\\" />
#
#
#
#     </div>
#     <div slot="derivation">
#         <DisplayEquation equation="\\begin{aligned}            \\| \\vec{a} \\times \\vec{b} \\|^2            &= \\|\\vec{a}\\|^2 \\|\\vec{b}\\|^2            - (\\vec{a} \\cdot \\vec{b})^2 \\\\            &= a^2 b^2 - (a b \\cos\\theta)^2 \\\\            &= a^2 b^2 (1 - \\cos^2\\theta) \\\\            &= a^2 b^2 \\sin^2\\theta.            \\end{aligned}\\" />
#
#
#
#     </div>
#     <div slot="derivation">
#         <DisplayEquation equation="\\begin{aligned}            \\hat{k} \\times \\vec{a}            &= \\hat{k} \\times (a_1\\,\\hat\\imath + a_2\\,\\hat\\jmath) \\\\            & a_1 (\\hat{k} \\times \\hat\\imath) + a_2 (\\hat{k} \\times \\hat\\jmath) \\\\            &= a_1\\,\\hat\\jmath - a_2\\,\\hat\\imath \\\\            &= \\vec{a}^\\perp.            \\end{aligned}\\" />
#
#
#
#     </div>
#     <div slot="derivation">
#         <DisplayEquation equation="\\begin{aligned}\\operatorname{Comp}(\\vec{a}, \\vec{b}) \\cdot \\vec{b}&= \\Big(\\vec{a} - (\\vec{a} \\cdot \\hat{b})\\hat{b}\\Big) \\cdot \\vec{b} \\\\&= \\vec{a} \\cdot \\vec{b} - (\\vec{a} \\cdot \\hat{b})(\\hat{b} \\cdot \\vec{b}) \\\\&= a b \\cos\\theta - (a\\cos\\theta) b \\\\&= 0.\\end{aligned}\\" />
#
#
#
#     </div>
#     <div slot="derivation">
#         <DisplayEquation equation="\\begin{aligned}\\vec{a} &= a_i \\hat\\imath + a_j \\hat\\jmath + a_k \\hat{k}& \\vec{a} &= a_u \\hat{u} + a_v \\hat{v} + a_w \\hat{w}.\\end{aligned}\\" />
# <DisplayEquation equation="\\begin{aligned}\\hat{u} &= u_i \\hat\\imath + u_j \\hat\\jmath + u_k \\hat{k} \\\\\\hat{v} &= v_i \\hat\\imath + v_j \\hat\\jmath + v_k \\hat{k} \\\\\\hat{w} &= w_i \\hat\\imath + w_j \\hat\\jmath + w_k \\hat{k}.\\end{aligned}\\" />
# <DisplayEquation equation="\\begin{aligned}\\vec{a} &= a_u \\hat{u} + a_v \\hat{v} + a_w \\hat{w} \\\\&= a_u (u_i \\hat\\imath + u_j \\hat\\jmath + u_k \\hat{k})+ a_v (v_i \\hat\\imath + v_j \\hat\\jmath + v_k \\hat{k})+ a_w (w_i \\hat\\imath + w_j \\hat\\jmath + w_k \\hat{k}) \\\\&= (a_u u_i + a_v v_i + a_w w_i) \\hat\\imath+ (a_u u_j + a_v v_j + a_w w_j) \\hat\\jmath+ (a_u u_k + a_v v_k + a_w w_k) \\hat{k} \\\\&= a_i \\hat\\imath + a_j \\hat\\jmath + a_k \\hat{k}.\\end{aligned}\\" />
#
#
#         <InlineEquation equation="\\vec{a}" />
# <InlineEquation equation="\\hat\\imath,\\hat\\jmath,\\hat{k}" />
# <InlineEquation equation="\\hat{u},\\hat{v},\\hat{w}" />
# <InlineEquation equation="\\hat{u},\\hat{v},\\hat{w}" />
# <InlineEquation equation="\\hat\\imath,\\hat\\jmath,\\hat{k}" />
# <InlineEquation equation="\\vec{a}" />
#
#     </div>
#     <div slot="derivation">
#         <DisplayEquation equation="\\begin{aligned}\\hat\\imath &= \\cos\\theta \\, \\hat{u} - \\sin\\theta \\, \\hat{v}& \\hat{u} &= \\cos\\theta \\, \\hat\\imath + \\sin\\theta \\, \\hat\\jmath \\\\\\hat\\jmath &= \\sin\\theta \\, \\hat{u} + \\cos\\theta \\, \\hat{v}& \\hat{v} &= -\\sin\\theta \\, \\hat\\imath + \\cos\\theta \\, \\hat\\jmath.\\end{aligned}\\" />
# <DisplayEquation equation="\\begin{aligned}i_u &= \\cos\\theta & i_v &= -\\sin\\theta& u_i &= \\cos\\theta & u_j &= \\sin\\theta \\\\j_u &= \\sin\\theta & j_v &= \\cos\\theta& v_i &= -\\sin\\theta & v_j &= \\cos\\theta.\\end{aligned}\\" />
#
#
#
#     </div>

# %%
<DisplayEquation equation="\\begin{aligned}I_{C,z} &= \\iiint_\\mathcal{B} \\rho (x^2 + y^2) \\,dx\\,dy\\,dz \\\\&= \\int_{-\\ell_z/2}^{\\ell_z/2} \\int_{-\\ell_y/2}^{\\ell_y/2} \\int_{-\\ell_x/2}^{\\ell_x/2}\\rho (x^2 + y^2) \\,dx\\,dy\\,dz \\\\&= \\int_{-\\ell_z/2}^{\\ell_z/2} \\int_{-\\ell_y/2}^{\\ell_y/2} \\left[\\rho \\left(\\frac{1}{3}x^3 + y^2 x\\right)\\right \\rho \\left(\\frac{1}{12}{\\ell_x}^3 y + \\frac{1}{3} y^3 \\ell_x \\right)\\right \\rho \\ell_x \\ell_y\\frac{1}{12}\\left( {\\ell_x}^2 + {\\ell_y}^2\\right) z \\right" />
# Out:
#   Cell In[53], line 1
#     <DisplayEquation equation="\\begin{aligned}I_{C,z} &= \\iiint_\\mathcal{B} \\rho (x^2 + y^2) \\,dx\\,dy\\,dz \\\\&= \\int_{-\\ell_z/2}^{\\ell_z/2} \\int_{-\\ell_y/2}^{\\ell_y/2} \\int_{-\\ell_x/2}^{\\ell_x/2}\\rho (x^2 + y^2) \\,dx\\,dy\\,dz \\\\&= \\int_{-\\ell_z/2}^{\\ell_z/2} \\int_{-\\ell_y/2}^{\\ell_y/2} \\left[\\rho \\left(\\frac{1}{3}x^3 + y^2 x\\right)\\right \\rho \\left(\\frac{1}{12}{\\ell_x}^3 y + \\frac{1}{3} y^3 \\ell_x \\right)\\right \\rho \\ell_x \\ell_y\\frac{1}{12}\\left( {\\ell_x}^2 + {\\ell_y}^2\\right) z \\right" />
#     ^
# SyntaxError: invalid syntax

# %%
e = r"""
\begin{align}
\frac{d}{dt}\left(S - S_0\right) &= \frac{d}{dt}\left( \sum_i \frac{Q_i}{T_{\text{b},i}} +\sigma \right) \\
\frac{dS}{dt} &=\sum_i \frac{\dot{Q}_i}{T_{\text{b},i}} +\dot{\sigma}.
\end{align}`
"""

print("<DisplayEquation equation=\"" + e.replace('\n', '').replace('\t', '').replace('$', '').replace(r'\[', '').replace(r'\]', '').replace("\\", r"\\") + "\" />")
# Out:
# <DisplayEquation equation="\\begin{align}\\frac{d}{dt}\\left(S - S_0\\right) &= \\frac{d}{dt}\\left( \\sum_i \\frac{Q_i}{T_{\\text{b},i}} +\\sigma \\right) \\\\\\frac{dS}{dt} &=\\sum_i \\frac{\\dot{Q}_i}{T_{\\text{b},i}} +\\dot{\\sigma}.\\end{align}`" />

# %%
print(e.replace('\n', '').replace('              ', '').replace('$', '').replace(r'\[', '').replace(r'\]', '').replace("\\", r"\\"))
# Out:
# \\vec{J} = \\int_{t_1}^{t_2}  \\vec{F} \\, dt

# %%
e = r"""
$dw = d\vec{p}_P$ and $u = \vec{r}_{OP}$
"""

print("<InlineEquation equation=\"" + e.replace('\n', '').replace('              ', '').replace('$', '').replace(r'\(', '').replace(r'\)', '').replace("\\", r"\\") + "\" />")
# Out:
# <InlineEquation equation="dw = d\\vec{p}_P and u = \\vec{r}_{OP}" />

# %% [markdown]
# <InlineEquation equation="\\vec{a}(t)" />
