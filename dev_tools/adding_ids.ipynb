# %%
from bs4 import BeautifulSoup
import os
import json
import shutil

# %%
course = 'thermodynamics'

for page in os.listdir(f'../src/pages/{course}'):
    with open(os.path.join(f'../src/pages/{course}', page)) as test_file:
        data = test_file.read()

    soup = BeautifulSoup(data, "html.parser")

    sections = soup.find_all(['section', 'subsection', 'subsubsection', 'subsubsubsection'])

    sections_list = []

    for section in sections:
        if section.name == 'section': continue
        try:
            section['id'] = section.attrs['title'].replace(' ', '_').replace(':', '').replace("\\", "").lower()
        except:
            print(page)
        sections_list.append([section.name, section['title'], section['id']])
        
    for section in sections_list:
        print(f"<li class='list-group-item py-0'><a class='text-decoration-none {section[0]}' href='#{section[2]}'>{section[1]}</a>")
# Out:
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#composite_thermodynamic_systems'>Composite Thermodynamic Systems</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#step_1_identify_known_states'>Step 1: Identify Known States</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#step_2_determine_unknowns'>Step 2: Determine Unknowns</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#step_3_write_energy_balances'>Step 3: Write Energy Balances</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#example_refrigeration_and_heat_pump_cycles'>Example: Refrigeration and Heat Pump Cycles</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#(color{red}_textbf{transient_systems})'>\\(\\color{red} \\textbf{Transient Systems}\\)</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#transient_vs._steady_state_example'>Transient vs. Steady State Example</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#carnot_cycle'>Carnot cycle</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#carnot_cycle_steps'>Carnot Cycle Steps</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#isothermal_processes'>Isothermal Processes</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#adiabatic_processes'>Adiabatic Processes</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#internal_energy_balance_of_the_system'>Internal Energy Balance of the System</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#thermal_efficiency'>Thermal Efficiency</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#a_rankine_cycle'>A Rankine Cycle</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#otto_cycle'>Otto Cycle</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#the_second_law_energy_dispersal'>The Second Law: Energy dispersal</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#clausius_statement_of_the_second_law'>Clausius Statement of the Second Law</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#expansion'>Expansion</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#directionality'>Directionality</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#kelvin-planck_statement_of_the_second_law'>Kelvin-Planck Statement of the Second Law</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#clausius_inequality'>Clausius Inequality</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#reversible_process'>Reversible Process</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#internally_reversible_cycles'>Internally Reversible Cycles</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#what_is_entropy?'>What is Entropy?</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#differential_form_of_the_closed_system_energy_balance'>Differential form of the closed system energy balance</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#specific_entropy_of_an_ideal_gas'>Specific Entropy of an Ideal Gas</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#differential_form_of_the_enthalpy_equation'>Differential form of the enthalpy equation</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#entropy_balance'>Entropy Balance</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#entropy_balance_and_multiple_heat_transfer_events'>Entropy Balance and multiple heat transfer events</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#rate_of_change_of_entropy'>Rate of Change of Entropy</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#microstates'>Microstates</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#principal_of_superposition'>Principal of Superposition</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#open_system_entropy_rate_balance'>Open System Entropy Rate Balance</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#heat'>Heat</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#work'>Work</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#(pv)_work'>\\(pV\\) work</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#shaft_work'>Shaft work</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#closed_system_energy_rate_balance'>Closed System Energy Rate Balance</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#closed_system_energy_balance'>Closed System Energy Balance</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#energy_transfer_via_mass_flow'>Energy Transfer via Mass Flow</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#internal_energy_change_via_mass_flow'>Internal Energy Change via Mass Flow</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#(pv)_work_done_via_mass_flow'>\\(pV\\) Work Done via Mass Flow</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#total_internal_energy_change_via_mass_flow'>Total Internal Energy Change via Mass Flow</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#relative_specific_enthalpy'>Relative Specific Enthalpy</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#internal_energy_rate_balance'>Internal Energy Rate Balance</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#total_energy_balance'>Total Energy Balance</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#total_energy_rate_balance'>Total Energy Rate Balance</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#phases_of_matter'>Phases of matter</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#phase_diagrams'>Phase Diagrams</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#critical_values_and_ideal_gases'>Critical Values and Ideal Gases</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#ideal_gases'>Ideal Gases</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#ideal_gas_assumptions'>Ideal Gas Assumptions</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#equation_of_state'>Equation of State</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#temperature_effects'>Temperature Effects</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#incompressible_fluids'>Incompressible Fluids</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#internal_energy_of_incompressible_fluids'>Internal Energy of Incompressible Fluids</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#specific_heat_of_incompressible_fluids'>Specific Heat of Incompressible Fluids</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#specific_entropy_change_of_incompressible_fluids'>Specific Entropy Change of Incompressible Fluids</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#nozzle'>Nozzle</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#diffuser'>Diffuser</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#turbine'>Turbine</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#compressor'>Compressor</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#pump'>Pump</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#throttling_device'>Throttling device</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#heat_exchanger'>Heat Exchanger</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#system,_boundaries_and_surroundings'>System, boundaries and surroundings</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#types_of_systems_closed,_open,_and_isolated_systems'>Types of Systems: Closed, Open, and Isolated Systems</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#units_of_interest'>Units of Interest</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#typical_units_in_si_and_english_systems'>Typical Units in SI and English Systems</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#useful_conversions'>Useful Conversions</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#useful_constants'>Useful Constants</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#helpful_math_expressions'>Helpful Math Expressions</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#mass_and_mass_flow'>Mass and Mass Flow</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#volume_and_volume_flow'>Volume and Volume Flow</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#volume_flow'>Volume Flow</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsection' href='#energy_and_energy_flow'>Energy and Energy Flow</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#internal_energy'>Internal Energy</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#potential_energy'>Potential Energy</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#kinetic_energy'>Kinetic Energy</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#enthalpy'>Enthalpy</a>
# <li class='list-group-item py-0'><a class='text-decoration-none subsubsection' href='#entropy'>Entropy</a>

# %%
course = 'dyn'
page = 'rigid_body_kinematics.astro'

with open(os.path.join(f'../src/pages/{course}', page)) as test_file:
    data = test_file.read()

soup = BeautifulSoup(data, "html.parser")

sections = soup.find_all(['section', 'subsection', 'subsubsection', 'subsubsubsection'])

sections_list = []

for section in sections:
    
    try:
        section['id'] = section.attrs['title'].replace(' ', '_').replace(':', '').lower()
    except:
        print(page)
    print([section.name, section['title'], section['id']])
# Out:
# ['section', 'Rigid Body Kinematics', 'rigid_body_kinematics']
# ['subsection', 'Rigid bodies', 'rigid_bodies']
# ['subsection', 'Rotating rigid bodies', 'rotating_rigid_bodies']
# ['subsection', 'Points on rigid bodies', 'points_on_rigid_bodies']
# ['subsection', 'Rigid bodies in 2D', 'rigid_bodies_in_2d']
# ['subsection', 'Constrained motion', 'constrained_motion']
# ['subsubsection', 'Constraint forces', 'constraint_forces']
# ['subsection', 'Gears', 'gears']
# ['subsubsection', 'Standard sign convention', 'standard_sign_convention']
# ['subsubsection', 'Accelerations in contact (no slip)', 'accelerations_in_contact_(no_slip)']
# ['subsection', 'Applications', 'applications']
# ['subsubsection', 'Steering geometry', 'steering_geometry']
# ['subsubsubsection', 'Turning rigid bodies', 'turning_rigid_bodies']
# ['subsubsection', 'Knee Joint', 'knee_joint']
# ['subsubsection', "Suspensions with Watt's linkage", "suspensions_with_watt's_linkage"]
# ['subsubsection', 'Aerobie Orbiter', 'aerobie_orbiter']

# %%
types = ['section', 'subsection', 'subsubsection', 'subsubsubsection']

types.reverse()

res = {t: [] for t in types}

found = False
skips = 0

for t in types:
    for i, vali in enumerate(sections_list):

        if vali[0] == t:
            for j, valj in enumerate(sections_list[i:]):
                valid = True
                #print(j+i, len(sections_list))
                if valj[0] != t or j + i == len(sections_list) - 1:
                    final_index = j+i+1 if j + i == len(sections_list) - 1 else j+i
                    for r in res[t]:
                        if i in r:
                            valid = False
                            break
                    if valid:
                        res[t].append([n for n in range(i, final_index)])
                    #print(t, i, j)
                    break

types.reverse()

children = {
    'section': 'subsection',
    'subsection': 'subsubsection',
    'subsubsection': 'subsubsubsection',
}

html = ''



for i, (t, name, id) in enumerate(sections_list):
    if i == len(sections_list) - 1:
        break

    if sections_list[i+1][0] == children[t]:
        for j, valj in enumerate(sections_list[i+1:]):
            if sections_list[j+1][0] == children[t]:
                print(valj)

sections_list
# Out:
# ['subsection', 'Units', 'units']
# ['subsection', 'Stress under general loading conditions', 'stress_under_general_loading_conditions']
# ['subsection', 'Support Reactions', 'support_reactions']
# ['subsection', 'Allowable Strength Design', 'allowable_strength_design']
# ['subsubsection', 'Stress Tensor', 'stress_tensor']
# ['subsection', 'Support Reactions', 'support_reactions']
# ['subsection', 'Allowable Strength Design', 'allowable_strength_design']
# [['section', 'Stress', 'stress'],
#  ['subsection', 'Units', 'units'],
#  ['subsection',
#   'Stress under general loading conditions',
#   'stress_under_general_loading_conditions'],
#  ['subsubsection',
#   'Average Normal Stress - Axial Loading',
#   'average_normal_stress_-_axial_loading'],
#  ['subsubsection', 'Average Shear Stress', 'average_shear_stress'],
#  ['subsubsection', 'Stress Tensor', 'stress_tensor'],
#  ['subsection', 'Support Reactions', 'support_reactions'],
#  ['subsection', 'Allowable Strength Design', 'allowable_strength_design']]

# %%
cleaned = sorted([file.replace('.astro', '')  for file in os.listdir('../src/components') if '.astro' in file])
cleaned.reverse()
replacements = {clean.lower(): clean for clean in cleaned}

for page in os.listdir('../src/pages/sol'):

    if '_o.astro' in path:
        continue

    with open(os.path.join('../src/pages/sol', page)) as test_file:
        data = test_file.read()

    soup = BeautifulSoup(data, "html.parser")

    sections = soup.find_all(['section', 'subsection', 'subsubsection', 'subsubsubsection'])

    sections_list = []

    for section in sections:
        section['id'] = section.attrs['title'].replace(' ', '_').replace(':', '').lower()

        sections_list.append([section.name, section['title'], section['id']])

    json_path = os.path.join('../public/sol/trees', page.replace('_o.astro', '.json'))
    json.dump(sections_list, open(json_path, 'w'), indent=2)

    for section in sections:
        section['id'] = section.attrs['title'].replace(' ', '_').replace(':', '').replace("'", '').lower()

    with open(os.path.join('../src/pages/sol', page.replace('_o.astro', '.astro')), 'w') as dump_file:
        string = str(soup)
        
        for wrong, correct in replacements.items():
            string = string.replace(wrong, correct)
        string = string.replace('<layout', '<Layout').replace('</layout', '</Layout').replace('></InlineEquation>' , ' />')
        dump_file.write(string)

# %%
cleaned = sorted([file.replace('.astro', '')  for file in os.listdir('../src/components') if '.astro' in file])
cleaned.reverse()
replacements = {clean.lower(): clean for clean in cleaned}

# %%
replacements
# Out:
# {'warning': 'Warning',
#  'subsubsubsection': 'SubSubSubSection',
#  'subsubsection': 'SubSubSection',
#  'subsection': 'SubSection',
#  'sidebarcontainer': 'SidebarContainer',
#  'section': 'Section',
#  'searchbar': 'Searchbar',
#  'row': 'Row',
#  'redtext': 'RedText',
#  'prairiedrawcanvas': 'PrairieDrawCanvas',
#  'navbar': 'Navbar',
#  'navtree': 'NavTree',
#  'latex': 'Latex',
#  'itemize': 'Itemize',
#  'item': 'Item',
#  'inlineequation': 'InlineEquation',
#  'image': 'Image',
#  'example': 'Example',
#  'enumerate': 'Enumerate',
#  'displayequationcustom': 'DisplayEquationCustom',
#  'displayequation': 'DisplayEquation',
#  'col': 'Col',
#  'center': 'Center',
#  'calloutcontainer': 'CalloutContainer',
#  'calloutcard': 'CalloutCard',
#  'bluetext': 'BlueText'}
